# %%
## Write a program to find check if a string has only ortal digits. Given string ['789', '123', '004']

# %%
strings = ['789', '123', '004']
def is_Octal(s):
    return all(c in '01234567' for c in s)
for s in strings:
    if is_Octal(s):
               print(f"'{s}'is an octal string.")
    else:
               print(f"'{s}' is Not an octal string.")
# Out:
# '789' is Not an octal string.
# '123'is an octal string.
# '004'is an octal string.

# %%
## Extract the user id, domain name and suffix from the following email addresses. 
## emails = """ zuck@facebook.com  sunder33@google.com  jeff42@amazon.com"""

# %%
import re

emails = """ zuck@facebook.com 
sunder33@google.com  
jeff42@amazon.com"""

pattern = r'([\w\.]+)@([\w\.]+)\.(\w+)'
matches = re.findall(pattern, emails)

for user, domain, suffix in matches:
    print(f"UserID: {user}, Domain: {domain}, suffix: {suffix}")
# Out:
# UserID: zuck, Domain: facebook, suffix: com
# UserID: sunder33, Domain: google, suffix: com
# UserID: jeff42, Domain: amazon, suffix: com

# %%
## Split the following irregular sentence into proper words.
## sentence = """A, very very; irregular sentence""" 
## experted outout: A very very irregular sentence

# %%
import re

sentence = """A, very very; irregular_sentence"""
sentence = sentence.replace('_', ' ')
cleaned = ' '.join(re.findall(r'\w+', sentence))

print(cleaned)
# Out:
# A very very irregular sentence

# %%
## Clean up the following twert so that it contains only the user's message. That is, remove all URLs, hashtags, mentions, punctuations, RTs and CCs.
# tweet = '''Good advice! RT @TheNextWeb: What I would do differently if I was learning to code today 
## http://t.co/lbwej0pxOd cc: @garybernhardt #rstats'''
##desired_output = 'Good advice What I would do differently if I was learning to code today'

# %%
import re

tweet = '''Good advice! RT @TheNextWeb: What I would do differently if I was learning to code today
http://t.co/lbwej@px0d cc: @garybernhardt #rstats'''

def clean_tweet(text):
    text = re.sub(r'\bRT\b|\bcc\b', '', text)
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

cleaned = clean_tweet(tweet)
print(cleaned)
# Out:
# Good advice What I would do differently if I was learning to code today

# %%
## Extract all the text portions between the tags from the following HTML page:
# https://raw.githubusercontent.com/selva86/datasets/master/sample.html

# Code to retrieve the HTML page is given below:
# import requests
# r  = requests.get("https://raw.githubusercontent.com/selva66/datasets/master/sample.html")
# r.text  # html text is contained here

# desired output = ['Your Title Here', 'Link Name', 'This is a Header, This is a Medium Header', 
#                 'This is a new paragraph!', 'This is a anothor paragraph!', 'This is a new sentence without paragraph break, in bold italics. ']

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("https://raw.githubusercontent.com/selva86/datasets/master/sample.html")
html_content = r.text
soup = BeautifulSoup(html_content, 'html.parser')
output = []
output.append(soup.title.string if soup.title else '') 
output.append(soup.a.get_text(strip=True) if soup.a else '')
headers = soup.find_all(['h1', 'h2'])
header_text = ', '.join([tag.get_text(strip=True) for tag in headers])
output.append(header_text)
for p in soup.find_all('p'):
    para_text = p.get_text(strip=True)
    if para_text:
        output.append(para_text)
bold_italic = soup.find('b')
if bold_italic and bold_italic.find('i'):
    sentence = bold_italic.get_text(strip=True)
    output.append(sentence)
print(output)
# Out:
# ['Your Title Here', 'Link Name', 'This is a Header, This is a Medium Header', 'This is a new paragraph!', 'This is a another paragraph!']

# %%
## Given below list of words, identify the words that begin and end with the same character.
# civic
# trust
# widows
# maximum
# museums
# aa
# as

# %%
words = ['civic', 'trust', 'widows', 'maximum', 'museums', 'aa', 'as']
matching_words = [word for word in words if word[0] == word[-1]]
print("Words that begin and end with the same character:", matching_words)
# Out:
# Words that begin and end with the same character: ['civic', 'trust', 'maximum', 'aa']
